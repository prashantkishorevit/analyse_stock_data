# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import numpy as np
ticker = "TITAN.NS"
import os
print(os.getcwd())
# os.chdir("../")
print(os.getcwd())
from technical_indicator import moving_average as ma
# Out:
# C:\Users\Prashant\courses\analyse_stock_data
# C:\Users\Prashant\courses\analyse_stock_data

# %%
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option("mode.chained_assignment", None)

# %%
# Valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
# Valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo

df = yf.download(ticker,period="5y",interval="1d")
df.dropna(inplace=True) # drop NA value from df data frame
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Calculate 50-days, 150-days and 200-days EMA
days=[50,150,200]
for i in days:
    ma.ema(df, days=i)

# %%
# Condition to match EMA cross over early stage of stock movement
# 1. 50-days EMA > 150-days EMA > 200-days EMA
# 2. Current Closing Price > 50-days EMA
# 3. 50-days EMA should not be too far from 150-days EMA.(50-days EMA < 2% of 150-days EMA)
# 4. Current closing price should not be too far from 50-days EMA. (Closing Price < 2% of 5-days EMA)

# save result in new data frame: result_df

result_df = df.loc[(df['150days_ema'] > df['200days_ema']) & (df['50days_ema'] > df['150days_ema']) & 
                   (df['50days_ema'] < df['150days_ema']*1.02) &
                 (df['Close'] > df['50days_ema']) &
                    (df['Close'] < df['50days_ema']*(1.02))]
# Out:
# Timestamp('2012-07-19 00:00:00')

# %%
# Create new Empty DataFrame that calculate 1 year return

result_1_year = pd.DataFrame()
result_1_year['Current_Close_Price'] = np.nan # Current Closing Price from result_df data frame
result_1_year['After_1year_Closing_Price'] = np.nan # Closing Price After 1 year from "Current Closing Price"

# %%
# Adding data to result_1_year datafame

for i in range(len(result_df.index)):
    result_1_year['Current_Close_Price'] = result_df['Close']
    try:
        result_1_year['After_1year_Closing_Price'][i] = df[df.index == (result_df.index[i] + timedelta(365))]['Close'][0]
    except Exception as e:
        print("Excepton", e)
# Out:
# 17

# %%
# Calculate % of profit/loss in 1 year

result_1_year['gain_or_loss'] = ((result_1_year['After_1year_Closing_Price'] - result_1_year['Current_Close_Price'])
        /result_1_year['Current_Close_Price'])*100

# %%
# Saving Result to Excel sheet

result_1_year.to_excel("result_{}.xlsx".format(ticker))

# %%
# rslt_df_after_2010 = rslt_df.loc[rslt_df['years'] > 2010]
rslt_df_after_2015
# Out:
#              Open   High    Low  Close  Adj Close   Volume  200days_ema  \
# Date
# 2017-01-10 598.10 608.40 597.65 607.17     594.31  2773058       594.29
# 2017-01-11 608.75 619.05 607.75 617.00     603.93  4671702       594.51
# 2017-01-12 617.50 621.85 612.75 617.50     604.42  1458158       594.74
# 2017-01-13 619.50 619.85 614.30 616.25     603.20  1925206       594.96
# 2017-01-16 616.75 624.72 616.40 623.83     610.61  1882932       595.24
# 2017-01-17 623.50 626.20 618.12 619.25     606.13  1779806       595.48
# 2017-01-18 620.45 628.00 620.42 621.30     608.14  2306444       595.74
# 2017-01-19 622.45 622.45 617.50 618.15     605.06  1756206       595.96
# 2017-01-20 618.00 622.50 615.00 618.17     605.08  6971034       596.18
# 2017-01-23 618.00 625.00 617.90 622.33     609.14  2396924       596.44
# 2017-01-24 625.00 635.75 624.62 633.78     620.35  5130932       596.82
# 2017-01-30 646.47 646.47 640.28 642.47     628.87  2659814       598.23
# 2017-01-31 641.20 646.35 638.50 643.33     629.70  3050520       598.68
# 2017-02-08 653.78 659.35 649.08 652.83     639.00  2470480       601.87
# 2017-02-09 654.70 659.95 646.28 648.83     635.08  2232688       602.34
# 2017-02-10 649.17 654.38 649.00 651.80     637.99  1648368       602.83
# 2017-02-13 653.78 657.50 649.60 655.10     641.22  1397896       603.35
# 2017-02-14 657.00 657.00 652.00 655.55     641.66  1223030       603.87
#
#             150days_ema  50days_ema  difference(150days_ema-200days_ema)  \
# Date
# 2017-01-10       601.29      602.43                                 7.00
# 2017-01-11       601.50      603.00                                 6.98
# 2017-01-12       601.71      603.57                                 6.97
# 2017-01-13       601.90      604.06                                 6.95
# 2017-01-16       602.19      604.84                                 6.95
# 2017-01-17       602.42      605.40                                 6.94
# 2017-01-18       602.67      606.03                                 6.93
# 2017-01-19       602.87      606.50                                 6.91
# 2017-01-20       603.08      606.96                                 6.89
# 2017-01-23       603.33      607.56                                 6.89
# 2017-01-24       603.73      608.59                                 6.92
# 2017-01-30       605.34      612.66                                 7.11
# 2017-01-31       605.84      613.86                                 7.16
# 2017-02-08       609.51      622.33                                 7.64
# 2017-02-09       610.03      623.37                                 7.69
# 2017-02-10       610.58      624.49                                 7.75
# 2017-02-13       611.17      625.69                                 7.82
# 2017-02-14       611.76      626.86                                 7.89
#
#             years
# Date
# 2017-01-10   2017
# 2017-01-11   2017
# 2017-01-12   2017
# 2017-01-13   2017
# 2017-01-16   2017
# 2017-01-17   2017
# 2017-01-18   2017
# 2017-01-19   2017
# 2017-01-20   2017
# 2017-01-23   2017
# 2017-01-24   2017
# 2017-01-30   2017
# 2017-01-31   2017
# 2017-02-08   2017
# 2017-02-09   2017
# 2017-02-10   2017
# 2017-02-13   2017
# 2017-02-14   2017

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# import datetime as dt

# df['years'] =  df.index.year
df.tail()
# df_new = df.groupby('years')
# type(df_new)
# df_new.size()
# years = list(set(dates))
# years
# x = [dt.datetime(d,'%m/%d/%Y').date() for d in dates]
# dates[0].year
# y = range(len(dates))
# Out:
#              Open   High    Low  Close  Adj Close         Volume  30days_ema  \
# Date
# 2020-11-16 187.10 192.00 182.70 191.70     191.70 141,838,503.00      186.67
# 2020-11-23 192.00 197.95 188.65 193.65     193.65 165,859,802.00      187.12
# 2020-11-30 193.65 199.35 192.40 198.20     198.20  94,480,668.00      187.83
# 2020-12-07 198.20 217.95 197.60 216.30     216.30 231,781,748.00      189.67
# 2020-12-14 217.95 218.60 209.75 214.50     214.50 115,958,540.00      191.27
#
#             40days_ema  difference(30days_ema-40days_ema)  years
# Date
# 2020-11-16      191.98                              -5.31   2020
# 2020-11-23      192.06                              -4.94   2020
# 2020-11-30      192.36                              -4.53   2020
# 2020-12-07      193.53                              -3.86   2020
# 2020-12-14      194.55                              -3.28   2020

# %%
plt.rcParams["figure.figsize"] = [15,7]
plt.axhline(y=0.0, color='r', linestyle='-')
plt.plot(df['years'], df["difference(30days_ema-40days_ema)"])

# %%
plt.rcParams["figure.figsize"] = [15,7]
plt.axhline(y=0.0, color='r', linestyle='-')
plt.plot(df.index, df["difference(30days_ema-40days_ema)"])
# plt.plot(df.index, df["30days_ema"])
# plt.plot(df.index, df["40days_ema"])

# plt.hist(years, df["difference(30days_ema-40days_ema)"], histtype='bar', rwidth=1)
